# %% [markdown]
# ## Student Information

# %%
student_name= "Uzair"
age = "19"
city = "Karachi"
student_status = True

# %%
print(student_name,age,city,student_status)
# Out:
# Uzair 19 Karachi True

# %% [markdown]
# ## Data Type

# %%
sting = "uzair"
integer = 11
floats = 2.1
boolean =  True
print(sting , type(sting))
print(integer , type(integer))
print(floats , type(floats))
print(boolean , type(boolean))
# Out:
# uzair <class 'str'>
# 11 <class 'int'>
# 2.1 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# # Arthematics and Operators

# %%
number1=4
number2=10
print(number1+number2)
print(number1-number2)
print(number1*number2)
print(number1%number2)
print(number1**number2)
print(number1 / number2)
# Out:
# 14
# -6
# 40
# 4
# 1048576
# 0.4

# %% [markdown]
# # students marks calculation

# %%
urdu=50
english=55
math=90
total = urdu + english + math
arg=total/3
print(total)
# Out:
# 195

# %% [markdown]
# # Shopping Bills

# %%
product_price= 100
quantity=10 
total_bill= product_price*quantity

# %%
total_bill = 100 * 10
print(total_bill)
# Out:
# 1000

# %% [markdown]
# # Rectangle Area

# %%
lenght = 1000
width = 500
area = lenght * width
print(area)
# Out:
# 500000

# %%
print("area")
# Out:
# area

# %% [markdown]
# # Time Convertor

# %%
hours = minutes / 10
minutes = 250
remaining_minutes = hours / minutes
print(remaining_minutes)
print(hours)
print(minutes)
# Out:
# 1.2
# 300.0
# 250

# %% [markdown]
# # Student Eligibility

# %%
marks = 50
attendance = 75
eligible = marks >= 50 and attendance >= 75
print(eligible)
# Out:
# True

# %%
a = True
b = False
And_Operator = a and b 
print(And_Operator)
Or_Operator= a or b
print(Or_Operator)
Not_Operator = not a
print(Not_Operator)
Not_Operator = not b 
print(Not_Operator)
# Out:
# False
# True
# False
# True

# %% [markdown]
# # Final Challange

# %% [markdown]
# # Student Report

# %%
Student_Name = "Uzair"
Age = 19
English = 21
Urdu = 80
Mathematic = 90
Attendence = 80
Total_Marks = English + Urdu + Mathematic
Average = Total_Marks /3
Average_Condition = (Average >=75)
Attendence_Condition = (Attendence >=50)
Student_Elibility = Average_Condition and Attendence_Condition
print("Student_Name = ", Student_Name)
print("Age = ", Age)
print("Total_Marks =", Total_Marks)
print("Average = ", Average )
print("Student_Elibility = ", Student_Elibility )
# Out:
# Student_Name =  Uzair
# Age =  19
# Total_Marks = 191
# Average =  63.666666666666664
# Student_Elibility =  False
